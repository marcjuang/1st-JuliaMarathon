# %% [markdown]
# # Julia 基礎圖表繪製: Plots 套件
#
# ## 作業 023：繪製 3D 函數
#
# 練習繪製 3D 函數：$z = x^2 - y^2$，$x$ 範圍於 $-5 \sim 5$，$y$ 範圍於 $-5 \sim 5$ 之間。（請完成以下程式碼）

# %%
using Plots

# %%
n = 1000
x = range(-5., stop=5., length=n)
y = range(-5., stop=5., length=n)
# Out:
# -5.0:0.01001001001001001:5.0

# %%
f(x,y) = x^2 + y^2
# Out:
# f (generic function with 1 method)

# %%
@gif for i in range(0, stop=2π, length=n)
    p = plot(x, y, f, st=:surface)
    plot!(p, camera=(15*cos(i), 40))
end
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\Marc Juang\julia\Course\tmp.gif
# └ @ Plots C:\Users\Marc Juang\.julia\packages\Plots\nnd5O\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\Marc Juang\\julia\\Course\\tmp.gif")
